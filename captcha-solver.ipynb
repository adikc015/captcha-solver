# %%
import cv2
import string
import numpy as np
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

import kagglehub

# Download latest version
path = kagglehub.dataset_download("fournierp/captcha-version-2-images")
print("Path to dataset files:", path)

sym = string.ascii_lowercase + "0123456789"
num_sym = len(sym)

# Shape of an image
img_shape = (50, 200, 1)

# Number of symbols
print("Number of symbols:", num_sym)

def create_model():
    """Create and return the CNN model for CAPTCHA solving"""
    # Input layer
    img = layers.Input(shape=img_shape)

    # Convolutional layers
    out = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(img)
    out = layers.MaxPooling2D(padding='same')(out)

    out = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = layers.MaxPooling2D(padding='same')(out)

    out = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = layers.BatchNormalization()(out)
    out = layers.MaxPooling2D(padding='same')(out)

    out = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = layers.MaxPooling2D(padding='same')(out)

    # Flatten the output
    flatten = layers.Flatten()(out)  # Fixed: use 'out' not undefined 'flatten'

    # Create 5 outputs for 5 characters
    outputs = []
    for _ in range(5):
        x = layers.Dense(128, activation='relu')(flatten)  # Fixed: use 'flatten'
        x = layers.Dropout(0.5)(x)
        x = layers.Dense(num_sym, activation='softmax')(x)
        outputs.append(x)

    # Compile the model
    model = Model(img, outputs)
    # For multi-output model, need metrics for each output
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy'] * 5  # One accuracy metric for each of the 5 outputs
    )

    return model

def preprocessing():
    """Preprocess the CAPTCHA images and labels"""
    data_path = os.path.join(path, "samples/samples")

    if not os.path.exists(data_path):
        raise FileNotFoundError(f"Data path does not exist: {data_path}")

    file_list = os.listdir(data_path)
    samp = len(file_list)

    X = np.zeros((samp, 50, 200, 1))
    y = np.zeros((5, samp, num_sym))

    valid_samples = 0
    for i, p in enumerate(file_list):
        img_path = os.path.join(data_path, p)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Warning: Could not read image {p}")
            continue

        p_target = p[:-4]  # Remove ".png"

        if len(p_target) == 5:  # CAPTCHA has 5 characters
            img = img / 255.0
            img = np.reshape(img, (50, 200, 1))

            t = np.zeros((5, num_sym))
            for j, l in enumerate(p_target):
                idx = sym.find(l)
                if idx != -1:  # Character found in symbol set
                    t[j, idx] = 1
                else:
                    print(f"Warning: Character '{l}' not found in symbol set")

            X[valid_samples] = img
            y[:, valid_samples] = t
            valid_samples += 1

    # Trim arrays to actual valid samples
    X = X[:valid_samples]
    y = y[:, :valid_samples]

    return X, y

def prediction(file_path):
    """Predict CAPTCHA from image file"""
    # Check if file exists
    if not os.path.exists(file_path):
        print(f"Error: File not found - {file_path}")
        return None

    # Read image
    img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)

    if img is None:
        print("Error: Could not read image")
        return None

    # Scale the image
    img = img / 255.0

    # Make prediction
    pred = model.predict(img[np.newaxis, :, :, np.newaxis])

    # Convert predictions to characters
    captcha = ''
    for i in range(5):
        idx = np.argmax(pred[i])
        captcha += sym[idx]

    return captcha

# Main execution
print("Starting preprocessing...")
X, y = preprocessing()
print(f"Loaded {X.shape[0]} samples")

# Convert y into list of 5 arrays (one for each character position)
y_list = [y[i] for i in range(5)]

# Split train/test data
split_idx = int(0.8 * len(X))  # Use 80% for training
X_train, y_train = X[:split_idx], [arr[:split_idx] for arr in y_list]
X_test, y_test = X[split_idx:], [arr[split_idx:] for arr in y_list]

print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")

# Create model
print("Creating model...")
model = create_model()

# Display model summary
model.summary()

# Train the model (removed duplicate training)
print("Starting training...")
history = model.fit(
    X_train, y_train,
    batch_size=64,
    epochs=50,
    verbose=1,
    validation_split=0.2
)

# Plot training curves
plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy (for the first character output, pattern is similar for others)
plt.subplot(1, 2, 2)
plt.plot(history.history['dense_1_accuracy'], label='Train Acc (Char 1)')
plt.plot(history.history['val_dense_1_accuracy'], label='Val Acc (Char 1)')
plt.title('Accuracy Curve (Char 1)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/fournierp/captcha-version-2-images?dataset_version_number=2...
# 100%|██████████| 17.4M/17.4M [00:01<00:00, 13.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fournierp/captcha-version-2-images/versions/2
# Number of symbols: 36
# Starting preprocessing...
# Loaded 1070 samples
# Training samples: 856
# Testing samples: 214
# Creating model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 50, 200,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 50, 200,   │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 25, 100,   │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 25, 100,   │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 13, 50,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 13, 50,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 13, 50,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 7, 25,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 7, 25,     │    147,584 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 4, 13,     │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 6656)      │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    852,096 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │    852,096 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │    852,096 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │    852,096 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 128)       │    852,096 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 36)        │      4,644 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 36)        │      4,644 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 36)        │      4,644 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 36)        │      4,644 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 36)        │      4,644 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,524,468 (17.26 MB)
#  Trainable params: 4,524,212 (17.26 MB)
#  Non-trainable params: 256 (1.00 KB)
# Starting training...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - dense_1_accuracy: 0.0414 - dense_1_loss: 3.5770 - dense_3_accuracy: 0.0482 - dense_3_loss: 3.7549 - dense_5_accuracy: 0.0548 - dense_5_loss: 3.6357 - dense_7_accuracy: 0.0396 - dense_7_loss: 3.5888 - dense_9_accuracy: 0.0497 - dense_9_loss: 3.5999 - loss: 18.1574 - val_dense_1_accuracy: 0.1163 - val_dense_1_loss: 3.5647 - val_dense_3_accuracy: 0.0640 - val_dense_3_loss: 3.5627 - val_dense_5_accuracy: 0.0581 - val_dense_5_loss: 3.5679 - val_dense_7_accuracy: 0.0523 - val_dense_7_loss: 3.5643 - val_dense_9_accuracy: 0.1105 - val_dense_9_loss: 3.5654 - val_loss: 17.8246
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.0598 - dense_1_loss: 3.2912 - dense_3_accuracy: 0.0860 - dense_3_loss: 3.2543 - dense_5_accuracy: 0.0581 - dense_5_loss: 3.2952 - dense_7_accuracy: 0.0575 - dense_7_loss: 3.3007 - dense_9_accuracy: 0.0793 - dense_9_loss: 3.2935 - loss: 16.4368 - val_dense_1_accuracy: 0.1221 - val_dense_1_loss: 3.5525 - val_dense_3_accuracy: 0.0756 - val_dense_3_loss: 3.5478 - val_dense_5_accuracy: 0.0988 - val_dense_5_loss: 3.5527 - val_dense_7_accuracy: 0.1337 - val_dense_7_loss: 3.5515 - val_dense_9_accuracy: 0.1105 - val_dense_9_loss: 3.5530 - val_loss: 17.7574
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.1528 - dense_1_loss: 2.9993 - dense_3_accuracy: 0.1059 - dense_3_loss: 3.0886 - dense_5_accuracy: 0.0678 - dense_5_loss: 3.1249 - dense_7_accuracy: 0.0873 - dense_7_loss: 3.1737 - dense_9_accuracy: 0.0988 - dense_9_loss: 3.1433 - loss: 15.5318 - val_dense_1_accuracy: 0.0407 - val_dense_1_loss: 3.5348 - val_dense_3_accuracy: 0.0756 - val_dense_3_loss: 3.5287 - val_dense_5_accuracy: 0.0988 - val_dense_5_loss: 3.5375 - val_dense_7_accuracy: 0.0930 - val_dense_7_loss: 3.5341 - val_dense_9_accuracy: 0.0640 - val_dense_9_loss: 3.5387 - val_loss: 17.6739
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.2850 - dense_1_loss: 2.4100 - dense_3_accuracy: 0.2065 - dense_3_loss: 2.6896 - dense_5_accuracy: 0.2033 - dense_5_loss: 2.7042 - dense_7_accuracy: 0.1283 - dense_7_loss: 2.9552 - dense_9_accuracy: 0.1664 - dense_9_loss: 2.8622 - loss: 13.6274 - val_dense_1_accuracy: 0.0407 - val_dense_1_loss: 3.5117 - val_dense_3_accuracy: 0.0523 - val_dense_3_loss: 3.5072 - val_dense_5_accuracy: 0.0814 - val_dense_5_loss: 3.5192 - val_dense_7_accuracy: 0.0465 - val_dense_7_loss: 3.5151 - val_dense_9_accuracy: 0.1221 - val_dense_9_loss: 3.5235 - val_loss: 17.5774
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.4140 - dense_1_loss: 1.9104 - dense_3_accuracy: 0.2996 - dense_3_loss: 2.3094 - dense_5_accuracy: 0.2728 - dense_5_loss: 2.3294 - dense_7_accuracy: 0.1991 - dense_7_loss: 2.6122 - dense_9_accuracy: 0.2415 - dense_9_loss: 2.4988 - loss: 11.6644 - val_dense_1_accuracy: 0.0465 - val_dense_1_loss: 3.4714 - val_dense_3_accuracy: 0.1860 - val_dense_3_loss: 3.4680 - val_dense_5_accuracy: 0.0523 - val_dense_5_loss: 3.4918 - val_dense_7_accuracy: 0.0465 - val_dense_7_loss: 3.4797 - val_dense_9_accuracy: 0.1512 - val_dense_9_loss: 3.4851 - val_loss: 17.3972
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.6053 - dense_1_loss: 1.3075 - dense_3_accuracy: 0.4377 - dense_3_loss: 1.8227 - dense_5_accuracy: 0.3818 - dense_5_loss: 1.8815 - dense_7_accuracy: 0.2818 - dense_7_loss: 2.2809 - dense_9_accuracy: 0.3705 - dense_9_loss: 2.0361 - loss: 9.3315 - val_dense_1_accuracy: 0.1221 - val_dense_1_loss: 3.4518 - val_dense_3_accuracy: 0.1860 - val_dense_3_loss: 3.4578 - val_dense_5_accuracy: 0.0698 - val_dense_5_loss: 3.4768 - val_dense_7_accuracy: 0.0581 - val_dense_7_loss: 3.4708 - val_dense_9_accuracy: 0.1802 - val_dense_9_loss: 3.4694 - val_loss: 17.3285
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.6757 - dense_1_loss: 0.9501 - dense_3_accuracy: 0.5591 - dense_3_loss: 1.4095 - dense_5_accuracy: 0.5193 - dense_5_loss: 1.5238 - dense_7_accuracy: 0.3607 - dense_7_loss: 2.0783 - dense_9_accuracy: 0.4828 - dense_9_loss: 1.6872 - loss: 7.6527 - val_dense_1_accuracy: 0.2907 - val_dense_1_loss: 3.3699 - val_dense_3_accuracy: 0.3372 - val_dense_3_loss: 3.3951 - val_dense_5_accuracy: 0.1163 - val_dense_5_loss: 3.4281 - val_dense_7_accuracy: 0.1221 - val_dense_7_loss: 3.4323 - val_dense_9_accuracy: 0.2442 - val_dense_9_loss: 3.4260 - val_loss: 17.0536
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.7996 - dense_1_loss: 0.6138 - dense_3_accuracy: 0.6424 - dense_3_loss: 1.0995 - dense_5_accuracy: 0.5806 - dense_5_loss: 1.3295 - dense_7_accuracy: 0.4892 - dense_7_loss: 1.6528 - dense_9_accuracy: 0.5761 - dense_9_loss: 1.3308 - loss: 6.0287 - val_dense_1_accuracy: 0.4593 - val_dense_1_loss: 3.2288 - val_dense_3_accuracy: 0.4826 - val_dense_3_loss: 3.2964 - val_dense_5_accuracy: 0.2558 - val_dense_5_loss: 3.3565 - val_dense_7_accuracy: 0.3779 - val_dense_7_loss: 3.3537 - val_dense_9_accuracy: 0.3779 - val_dense_9_loss: 3.3231 - val_loss: 16.5614
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.8604 - dense_1_loss: 0.4534 - dense_3_accuracy: 0.7399 - dense_3_loss: 0.8724 - dense_5_accuracy: 0.6970 - dense_5_loss: 0.9917 - dense_7_accuracy: 0.5737 - dense_7_loss: 1.2956 - dense_9_accuracy: 0.6598 - dense_9_loss: 1.0539 - loss: 4.6689 - val_dense_1_accuracy: 0.8663 - val_dense_1_loss: 3.0815 - val_dense_3_accuracy: 0.6860 - val_dense_3_loss: 3.1777 - val_dense_5_accuracy: 0.4884 - val_dense_5_loss: 3.2182 - val_dense_7_accuracy: 0.5465 - val_dense_7_loss: 3.2870 - val_dense_9_accuracy: 0.6395 - val_dense_9_loss: 3.2096 - val_loss: 15.9782
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - dense_1_accuracy: 0.9161 - dense_1_loss: 0.3077 - dense_3_accuracy: 0.7773 - dense_3_loss: 0.6993 - dense_5_accuracy: 0.7783 - dense_5_loss: 0.6443 - dense_7_accuracy: 0.6611 - dense_7_loss: 1.1015 - dense_9_accuracy: 0.7437 - dense_9_loss: 0.8210 - loss: 3.5775 - val_dense_1_accuracy: 0.8953 - val_dense_1_loss: 2.8760 - val_dense_3_accuracy: 0.7267 - val_dense_3_loss: 3.0321 - val_dense_5_accuracy: 0.5291 - val_dense_5_loss: 3.1172 - val_dense_7_accuracy: 0.5930 - val_dense_7_loss: 3.1643 - val_dense_9_accuracy: 0.6105 - val_dense_9_loss: 3.0540 - val_loss: 15.2518
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9051 - dense_1_loss: 0.2840 - dense_3_accuracy: 0.7951 - dense_3_loss: 0.5814 - dense_5_accuracy: 0.8006 - dense_5_loss: 0.6099 - dense_7_accuracy: 0.6480 - dense_7_loss: 1.0422 - dense_9_accuracy: 0.7869 - dense_9_loss: 0.6409 - loss: 3.1582 - val_dense_1_accuracy: 0.9186 - val_dense_1_loss: 2.6428 - val_dense_3_accuracy: 0.8430 - val_dense_3_loss: 2.8175 - val_dense_5_accuracy: 0.6860 - val_dense_5_loss: 2.8991 - val_dense_7_accuracy: 0.6570 - val_dense_7_loss: 3.0106 - val_dense_9_accuracy: 0.7442 - val_dense_9_loss: 2.8659 - val_loss: 14.2471
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9503 - dense_1_loss: 0.1868 - dense_3_accuracy: 0.8538 - dense_3_loss: 0.4598 - dense_5_accuracy: 0.8152 - dense_5_loss: 0.5879 - dense_7_accuracy: 0.7213 - dense_7_loss: 0.7957 - dense_9_accuracy: 0.8341 - dense_9_loss: 0.4665 - loss: 2.4998 - val_dense_1_accuracy: 0.9128 - val_dense_1_loss: 2.4557 - val_dense_3_accuracy: 0.8721 - val_dense_3_loss: 2.6864 - val_dense_5_accuracy: 0.7151 - val_dense_5_loss: 2.8113 - val_dense_7_accuracy: 0.6977 - val_dense_7_loss: 2.8961 - val_dense_9_accuracy: 0.7907 - val_dense_9_loss: 2.7533 - val_loss: 13.6131
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.9390 - dense_1_loss: 0.1915 - dense_3_accuracy: 0.8802 - dense_3_loss: 0.3633 - dense_5_accuracy: 0.8633 - dense_5_loss: 0.4011 - dense_7_accuracy: 0.8071 - dense_7_loss: 0.6005 - dense_9_accuracy: 0.8591 - dense_9_loss: 0.4340 - loss: 1.9901 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 2.2461 - val_dense_3_accuracy: 0.9128 - val_dense_3_loss: 2.4436 - val_dense_5_accuracy: 0.8023 - val_dense_5_loss: 2.6014 - val_dense_7_accuracy: 0.7384 - val_dense_7_loss: 2.7120 - val_dense_9_accuracy: 0.8430 - val_dense_9_loss: 2.4957 - val_loss: 12.5120
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9509 - dense_1_loss: 0.1681 - dense_3_accuracy: 0.8746 - dense_3_loss: 0.3769 - dense_5_accuracy: 0.8774 - dense_5_loss: 0.3397 - dense_7_accuracy: 0.8189 - dense_7_loss: 0.5696 - dense_9_accuracy: 0.9027 - dense_9_loss: 0.3053 - loss: 1.7591 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 1.8655 - val_dense_3_accuracy: 0.9012 - val_dense_3_loss: 2.1409 - val_dense_5_accuracy: 0.8198 - val_dense_5_loss: 2.3170 - val_dense_7_accuracy: 0.7791 - val_dense_7_loss: 2.4528 - val_dense_9_accuracy: 0.8837 - val_dense_9_loss: 2.2529 - val_loss: 11.0423
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9554 - dense_1_loss: 0.1318 - dense_3_accuracy: 0.8597 - dense_3_loss: 0.3566 - dense_5_accuracy: 0.9186 - dense_5_loss: 0.2768 - dense_7_accuracy: 0.8322 - dense_7_loss: 0.5556 - dense_9_accuracy: 0.8831 - dense_9_loss: 0.3483 - loss: 1.6694 - val_dense_1_accuracy: 0.9593 - val_dense_1_loss: 1.7020 - val_dense_3_accuracy: 0.9186 - val_dense_3_loss: 2.0353 - val_dense_5_accuracy: 0.8488 - val_dense_5_loss: 2.1600 - val_dense_7_accuracy: 0.8140 - val_dense_7_loss: 2.3423 - val_dense_9_accuracy: 0.9012 - val_dense_9_loss: 2.1071 - val_loss: 10.3676
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9603 - dense_1_loss: 0.1140 - dense_3_accuracy: 0.9219 - dense_3_loss: 0.2439 - dense_5_accuracy: 0.8860 - dense_5_loss: 0.2809 - dense_7_accuracy: 0.8104 - dense_7_loss: 0.4539 - dense_9_accuracy: 0.8807 - dense_9_loss: 0.3413 - loss: 1.4350 - val_dense_1_accuracy: 0.9651 - val_dense_1_loss: 1.6878 - val_dense_3_accuracy: 0.9186 - val_dense_3_loss: 1.9676 - val_dense_5_accuracy: 0.8314 - val_dense_5_loss: 2.1652 - val_dense_7_accuracy: 0.7500 - val_dense_7_loss: 2.3590 - val_dense_9_accuracy: 0.8663 - val_dense_9_loss: 2.1775 - val_loss: 10.3783
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9492 - dense_1_loss: 0.1162 - dense_3_accuracy: 0.9093 - dense_3_loss: 0.2599 - dense_5_accuracy: 0.9157 - dense_5_loss: 0.2199 - dense_7_accuracy: 0.8469 - dense_7_loss: 0.4171 - dense_9_accuracy: 0.9333 - dense_9_loss: 0.2145 - loss: 1.2271 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 1.3267 - val_dense_3_accuracy: 0.9070 - val_dense_3_loss: 1.6725 - val_dense_5_accuracy: 0.8430 - val_dense_5_loss: 1.8481 - val_dense_7_accuracy: 0.7849 - val_dense_7_loss: 2.0538 - val_dense_9_accuracy: 0.9128 - val_dense_9_loss: 1.8265 - val_loss: 8.7479
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.9532 - dense_1_loss: 0.1330 - dense_3_accuracy: 0.9352 - dense_3_loss: 0.1974 - dense_5_accuracy: 0.9379 - dense_5_loss: 0.1885 - dense_7_accuracy: 0.8541 - dense_7_loss: 0.4122 - dense_9_accuracy: 0.9213 - dense_9_loss: 0.2190 - loss: 1.1509 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 1.1241 - val_dense_3_accuracy: 0.9128 - val_dense_3_loss: 1.3501 - val_dense_5_accuracy: 0.8895 - val_dense_5_loss: 1.4897 - val_dense_7_accuracy: 0.8198 - val_dense_7_loss: 1.7796 - val_dense_9_accuracy: 0.9128 - val_dense_9_loss: 1.3761 - val_loss: 7.1304
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.9696 - dense_1_loss: 0.0898 - dense_3_accuracy: 0.9186 - dense_3_loss: 0.2359 - dense_5_accuracy: 0.9362 - dense_5_loss: 0.1799 - dense_7_accuracy: 0.8541 - dense_7_loss: 0.3961 - dense_9_accuracy: 0.8920 - dense_9_loss: 0.2848 - loss: 1.1872 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 1.0766 - val_dense_3_accuracy: 0.9302 - val_dense_3_loss: 1.4506 - val_dense_5_accuracy: 0.8547 - val_dense_5_loss: 1.5773 - val_dense_7_accuracy: 0.7849 - val_dense_7_loss: 1.8719 - val_dense_9_accuracy: 0.9070 - val_dense_9_loss: 1.6247 - val_loss: 7.6167
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9688 - dense_1_loss: 0.1160 - dense_3_accuracy: 0.9255 - dense_3_loss: 0.2022 - dense_5_accuracy: 0.9365 - dense_5_loss: 0.1682 - dense_7_accuracy: 0.8608 - dense_7_loss: 0.3584 - dense_9_accuracy: 0.9336 - dense_9_loss: 0.2083 - loss: 1.0536 - val_dense_1_accuracy: 0.9651 - val_dense_1_loss: 0.8159 - val_dense_3_accuracy: 0.9302 - val_dense_3_loss: 1.2071 - val_dense_5_accuracy: 0.8895 - val_dense_5_loss: 1.3636 - val_dense_7_accuracy: 0.8140 - val_dense_7_loss: 1.6382 - val_dense_9_accuracy: 0.9244 - val_dense_9_loss: 1.3292 - val_loss: 6.3754
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9768 - dense_1_loss: 0.0834 - dense_3_accuracy: 0.9279 - dense_3_loss: 0.1978 - dense_5_accuracy: 0.9508 - dense_5_loss: 0.1531 - dense_7_accuracy: 0.8726 - dense_7_loss: 0.3314 - dense_9_accuracy: 0.9338 - dense_9_loss: 0.1873 - loss: 0.9527 - val_dense_1_accuracy: 0.9884 - val_dense_1_loss: 0.6200 - val_dense_3_accuracy: 0.9302 - val_dense_3_loss: 0.9868 - val_dense_5_accuracy: 0.9070 - val_dense_5_loss: 1.1147 - val_dense_7_accuracy: 0.8198 - val_dense_7_loss: 1.3926 - val_dense_9_accuracy: 0.9244 - val_dense_9_loss: 1.0955 - val_loss: 5.2216
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9707 - dense_1_loss: 0.0925 - dense_3_accuracy: 0.9323 - dense_3_loss: 0.2006 - dense_5_accuracy: 0.9463 - dense_5_loss: 0.1520 - dense_7_accuracy: 0.9253 - dense_7_loss: 0.2456 - dense_9_accuracy: 0.9332 - dense_9_loss: 0.1638 - loss: 0.8552 - val_dense_1_accuracy: 0.9709 - val_dense_1_loss: 0.6662 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 1.0002 - val_dense_5_accuracy: 0.8953 - val_dense_5_loss: 1.2295 - val_dense_7_accuracy: 0.8198 - val_dense_7_loss: 1.4491 - val_dense_9_accuracy: 0.9070 - val_dense_9_loss: 1.1901 - val_loss: 5.5530
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.9719 - dense_1_loss: 0.0805 - dense_3_accuracy: 0.9202 - dense_3_loss: 0.2129 - dense_5_accuracy: 0.9418 - dense_5_loss: 0.1692 - dense_7_accuracy: 0.9139 - dense_7_loss: 0.2619 - dense_9_accuracy: 0.9499 - dense_9_loss: 0.1430 - loss: 0.8672 - val_dense_1_accuracy: 1.0000 - val_dense_1_loss: 0.5179 - val_dense_3_accuracy: 0.9477 - val_dense_3_loss: 0.7893 - val_dense_5_accuracy: 0.8837 - val_dense_5_loss: 1.0180 - val_dense_7_accuracy: 0.8198 - val_dense_7_loss: 1.3110 - val_dense_9_accuracy: 0.9244 - val_dense_9_loss: 0.9034 - val_loss: 4.5509
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9708 - dense_1_loss: 0.0856 - dense_3_accuracy: 0.9485 - dense_3_loss: 0.1646 - dense_5_accuracy: 0.9375 - dense_5_loss: 0.1657 - dense_7_accuracy: 0.9220 - dense_7_loss: 0.2317 - dense_9_accuracy: 0.9507 - dense_9_loss: 0.1684 - loss: 0.8166 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 0.3921 - val_dense_3_accuracy: 0.9419 - val_dense_3_loss: 0.6668 - val_dense_5_accuracy: 0.9128 - val_dense_5_loss: 0.9019 - val_dense_7_accuracy: 0.8081 - val_dense_7_loss: 1.1695 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.7910 - val_loss: 3.9330
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9823 - dense_1_loss: 0.0608 - dense_3_accuracy: 0.9410 - dense_3_loss: 0.1566 - dense_5_accuracy: 0.9677 - dense_5_loss: 0.1155 - dense_7_accuracy: 0.9050 - dense_7_loss: 0.2524 - dense_9_accuracy: 0.9499 - dense_9_loss: 0.1341 - loss: 0.7200 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 0.3262 - val_dense_3_accuracy: 0.9651 - val_dense_3_loss: 0.5956 - val_dense_5_accuracy: 0.8837 - val_dense_5_loss: 0.7885 - val_dense_7_accuracy: 0.8314 - val_dense_7_loss: 0.9920 - val_dense_9_accuracy: 0.9360 - val_dense_9_loss: 0.7169 - val_loss: 3.4308
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9632 - dense_1_loss: 0.0897 - dense_3_accuracy: 0.9377 - dense_3_loss: 0.1660 - dense_5_accuracy: 0.9652 - dense_5_loss: 0.1024 - dense_7_accuracy: 0.9056 - dense_7_loss: 0.2536 - dense_9_accuracy: 0.9402 - dense_9_loss: 0.1676 - loss: 0.7787 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 0.2727 - val_dense_3_accuracy: 0.9302 - val_dense_3_loss: 0.5375 - val_dense_5_accuracy: 0.8953 - val_dense_5_loss: 0.7547 - val_dense_7_accuracy: 0.8314 - val_dense_7_loss: 0.9696 - val_dense_9_accuracy: 0.9244 - val_dense_9_loss: 0.6730 - val_loss: 3.2232
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.9737 - dense_1_loss: 0.0674 - dense_3_accuracy: 0.9269 - dense_3_loss: 0.1761 - dense_5_accuracy: 0.9712 - dense_5_loss: 0.1140 - dense_7_accuracy: 0.9204 - dense_7_loss: 0.2287 - dense_9_accuracy: 0.9515 - dense_9_loss: 0.1421 - loss: 0.7263 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 0.2068 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 0.4079 - val_dense_5_accuracy: 0.9012 - val_dense_5_loss: 0.6676 - val_dense_7_accuracy: 0.8314 - val_dense_7_loss: 0.8370 - val_dense_9_accuracy: 0.9186 - val_dense_9_loss: 0.5284 - val_loss: 2.6597
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9733 - dense_1_loss: 0.0734 - dense_3_accuracy: 0.9465 - dense_3_loss: 0.1574 - dense_5_accuracy: 0.9564 - dense_5_loss: 0.1207 - dense_7_accuracy: 0.9163 - dense_7_loss: 0.2696 - dense_9_accuracy: 0.9535 - dense_9_loss: 0.1444 - loss: 0.7647 - val_dense_1_accuracy: 0.9651 - val_dense_1_loss: 0.1771 - val_dense_3_accuracy: 0.9360 - val_dense_3_loss: 0.3847 - val_dense_5_accuracy: 0.9244 - val_dense_5_loss: 0.5949 - val_dense_7_accuracy: 0.8605 - val_dense_7_loss: 0.8046 - val_dense_9_accuracy: 0.9360 - val_dense_9_loss: 0.4871 - val_loss: 2.4549
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.9763 - dense_1_loss: 0.0695 - dense_3_accuracy: 0.9490 - dense_3_loss: 0.1443 - dense_5_accuracy: 0.9694 - dense_5_loss: 0.0897 - dense_7_accuracy: 0.9179 - dense_7_loss: 0.2066 - dense_9_accuracy: 0.9642 - dense_9_loss: 0.0997 - loss: 0.6094 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 0.2316 - val_dense_3_accuracy: 0.9593 - val_dense_3_loss: 0.4049 - val_dense_5_accuracy: 0.9012 - val_dense_5_loss: 0.6480 - val_dense_7_accuracy: 0.8314 - val_dense_7_loss: 0.9009 - val_dense_9_accuracy: 0.9302 - val_dense_9_loss: 0.5520 - val_loss: 2.7484
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9849 - dense_1_loss: 0.0565 - dense_3_accuracy: 0.9489 - dense_3_loss: 0.1392 - dense_5_accuracy: 0.9563 - dense_5_loss: 0.1355 - dense_7_accuracy: 0.9150 - dense_7_loss: 0.2475 - dense_9_accuracy: 0.9564 - dense_9_loss: 0.1387 - loss: 0.7172 - val_dense_1_accuracy: 0.9709 - val_dense_1_loss: 0.1200 - val_dense_3_accuracy: 0.9419 - val_dense_3_loss: 0.2607 - val_dense_5_accuracy: 0.9128 - val_dense_5_loss: 0.4639 - val_dense_7_accuracy: 0.8721 - val_dense_7_loss: 0.6017 - val_dense_9_accuracy: 0.9244 - val_dense_9_loss: 0.3980 - val_loss: 1.8538
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9801 - dense_1_loss: 0.0580 - dense_3_accuracy: 0.9516 - dense_3_loss: 0.1409 - dense_5_accuracy: 0.9632 - dense_5_loss: 0.1065 - dense_7_accuracy: 0.9305 - dense_7_loss: 0.1831 - dense_9_accuracy: 0.9501 - dense_9_loss: 0.1207 - loss: 0.6076 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 0.1136 - val_dense_3_accuracy: 0.9360 - val_dense_3_loss: 0.2954 - val_dense_5_accuracy: 0.8953 - val_dense_5_loss: 0.5091 - val_dense_7_accuracy: 0.8547 - val_dense_7_loss: 0.6128 - val_dense_9_accuracy: 0.9360 - val_dense_9_loss: 0.3836 - val_loss: 1.9277
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.9822 - dense_1_loss: 0.0378 - dense_3_accuracy: 0.9563 - dense_3_loss: 0.1400 - dense_5_accuracy: 0.9708 - dense_5_loss: 0.0776 - dense_7_accuracy: 0.9331 - dense_7_loss: 0.1940 - dense_9_accuracy: 0.9727 - dense_9_loss: 0.0762 - loss: 0.5250 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 0.0673 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 0.2189 - val_dense_5_accuracy: 0.9128 - val_dense_5_loss: 0.4815 - val_dense_7_accuracy: 0.8605 - val_dense_7_loss: 0.5666 - val_dense_9_accuracy: 0.9302 - val_dense_9_loss: 0.3378 - val_loss: 1.6798
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - dense_1_accuracy: 0.9930 - dense_1_loss: 0.0336 - dense_3_accuracy: 0.9543 - dense_3_loss: 0.1365 - dense_5_accuracy: 0.9464 - dense_5_loss: 0.1653 - dense_7_accuracy: 0.9308 - dense_7_loss: 0.1920 - dense_9_accuracy: 0.9683 - dense_9_loss: 0.0938 - loss: 0.6207 - val_dense_1_accuracy: 0.9884 - val_dense_1_loss: 0.0633 - val_dense_3_accuracy: 0.9593 - val_dense_3_loss: 0.2303 - val_dense_5_accuracy: 0.9070 - val_dense_5_loss: 0.4751 - val_dense_7_accuracy: 0.8721 - val_dense_7_loss: 0.6175 - val_dense_9_accuracy: 0.9360 - val_dense_9_loss: 0.3253 - val_loss: 1.7191
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.9802 - dense_1_loss: 0.0453 - dense_3_accuracy: 0.9604 - dense_3_loss: 0.1106 - dense_5_accuracy: 0.9513 - dense_5_loss: 0.1147 - dense_7_accuracy: 0.9507 - dense_7_loss: 0.1616 - dense_9_accuracy: 0.9550 - dense_9_loss: 0.1251 - loss: 0.5579 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 0.0583 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 0.1815 - val_dense_5_accuracy: 0.9302 - val_dense_5_loss: 0.4312 - val_dense_7_accuracy: 0.8547 - val_dense_7_loss: 0.5983 - val_dense_9_accuracy: 0.9535 - val_dense_9_loss: 0.2825 - val_loss: 1.5541
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9762 - dense_1_loss: 0.0672 - dense_3_accuracy: 0.9486 - dense_3_loss: 0.1241 - dense_5_accuracy: 0.9767 - dense_5_loss: 0.0656 - dense_7_accuracy: 0.9469 - dense_7_loss: 0.1650 - dense_9_accuracy: 0.9624 - dense_9_loss: 0.1138 - loss: 0.5360 - val_dense_1_accuracy: 0.9884 - val_dense_1_loss: 0.0424 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 0.1567 - val_dense_5_accuracy: 0.9302 - val_dense_5_loss: 0.3917 - val_dense_7_accuracy: 0.8721 - val_dense_7_loss: 0.5159 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.2957 - val_loss: 1.4065
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - dense_1_accuracy: 0.9756 - dense_1_loss: 0.0777 - dense_3_accuracy: 0.9393 - dense_3_loss: 0.1706 - dense_5_accuracy: 0.9692 - dense_5_loss: 0.0706 - dense_7_accuracy: 0.9367 - dense_7_loss: 0.1974 - dense_9_accuracy: 0.9805 - dense_9_loss: 0.0639 - loss: 0.5804 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 0.0492 - val_dense_3_accuracy: 0.9593 - val_dense_3_loss: 0.1711 - val_dense_5_accuracy: 0.9128 - val_dense_5_loss: 0.4171 - val_dense_7_accuracy: 0.8547 - val_dense_7_loss: 0.5296 - val_dense_9_accuracy: 0.9535 - val_dense_9_loss: 0.2592 - val_loss: 1.4309
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.9727 - dense_1_loss: 0.0728 - dense_3_accuracy: 0.9538 - dense_3_loss: 0.1255 - dense_5_accuracy: 0.9823 - dense_5_loss: 0.0563 - dense_7_accuracy: 0.9434 - dense_7_loss: 0.1557 - dense_9_accuracy: 0.9709 - dense_9_loss: 0.0853 - loss: 0.4956 - val_dense_1_accuracy: 0.9884 - val_dense_1_loss: 0.0382 - val_dense_3_accuracy: 0.9419 - val_dense_3_loss: 0.1763 - val_dense_5_accuracy: 0.9302 - val_dense_5_loss: 0.4206 - val_dense_7_accuracy: 0.8721 - val_dense_7_loss: 0.4908 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.2962 - val_loss: 1.4327
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9853 - dense_1_loss: 0.0499 - dense_3_accuracy: 0.9565 - dense_3_loss: 0.1122 - dense_5_accuracy: 0.9580 - dense_5_loss: 0.1174 - dense_7_accuracy: 0.9272 - dense_7_loss: 0.1815 - dense_9_accuracy: 0.9785 - dense_9_loss: 0.0675 - loss: 0.5291 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 0.0341 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 0.1474 - val_dense_5_accuracy: 0.9244 - val_dense_5_loss: 0.4433 - val_dense_7_accuracy: 0.8605 - val_dense_7_loss: 0.5104 - val_dense_9_accuracy: 0.9477 - val_dense_9_loss: 0.2491 - val_loss: 1.4043
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9900 - dense_1_loss: 0.0361 - dense_3_accuracy: 0.9501 - dense_3_loss: 0.1287 - dense_5_accuracy: 0.9672 - dense_5_loss: 0.0759 - dense_7_accuracy: 0.9524 - dense_7_loss: 0.1383 - dense_9_accuracy: 0.9751 - dense_9_loss: 0.0783 - loss: 0.4580 - val_dense_1_accuracy: 0.9709 - val_dense_1_loss: 0.0398 - val_dense_3_accuracy: 0.9535 - val_dense_3_loss: 0.1290 - val_dense_5_accuracy: 0.9302 - val_dense_5_loss: 0.3988 - val_dense_7_accuracy: 0.8953 - val_dense_7_loss: 0.4808 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.2141 - val_loss: 1.2770
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - dense_1_accuracy: 0.9836 - dense_1_loss: 0.0446 - dense_3_accuracy: 0.9552 - dense_3_loss: 0.1163 - dense_5_accuracy: 0.9738 - dense_5_loss: 0.0724 - dense_7_accuracy: 0.9214 - dense_7_loss: 0.1965 - dense_9_accuracy: 0.9717 - dense_9_loss: 0.0872 - loss: 0.5172 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 0.0436 - val_dense_3_accuracy: 0.9593 - val_dense_3_loss: 0.1116 - val_dense_5_accuracy: 0.9360 - val_dense_5_loss: 0.4015 - val_dense_7_accuracy: 0.8837 - val_dense_7_loss: 0.4602 - val_dense_9_accuracy: 0.9302 - val_dense_9_loss: 0.2628 - val_loss: 1.2857
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9775 - dense_1_loss: 0.0533 - dense_3_accuracy: 0.9616 - dense_3_loss: 0.1171 - dense_5_accuracy: 0.9755 - dense_5_loss: 0.0832 - dense_7_accuracy: 0.9400 - dense_7_loss: 0.1691 - dense_9_accuracy: 0.9822 - dense_9_loss: 0.0667 - loss: 0.4899 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 0.0366 - val_dense_3_accuracy: 0.9651 - val_dense_3_loss: 0.1223 - val_dense_5_accuracy: 0.9244 - val_dense_5_loss: 0.4398 - val_dense_7_accuracy: 0.8721 - val_dense_7_loss: 0.5282 - val_dense_9_accuracy: 0.9360 - val_dense_9_loss: 0.2667 - val_loss: 1.3925
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9805 - dense_1_loss: 0.0471 - dense_3_accuracy: 0.9675 - dense_3_loss: 0.1061 - dense_5_accuracy: 0.9825 - dense_5_loss: 0.0594 - dense_7_accuracy: 0.9512 - dense_7_loss: 0.1564 - dense_9_accuracy: 0.9801 - dense_9_loss: 0.0665 - loss: 0.4349 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 0.0293 - val_dense_3_accuracy: 0.9651 - val_dense_3_loss: 0.1198 - val_dense_5_accuracy: 0.9186 - val_dense_5_loss: 0.4780 - val_dense_7_accuracy: 0.8837 - val_dense_7_loss: 0.5050 - val_dense_9_accuracy: 0.9302 - val_dense_9_loss: 0.2474 - val_loss: 1.3946
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9910 - dense_1_loss: 0.0388 - dense_3_accuracy: 0.9529 - dense_3_loss: 0.1159 - dense_5_accuracy: 0.9733 - dense_5_loss: 0.0701 - dense_7_accuracy: 0.9478 - dense_7_loss: 0.1361 - dense_9_accuracy: 0.9563 - dense_9_loss: 0.1063 - loss: 0.4671 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 0.0235 - val_dense_3_accuracy: 0.9651 - val_dense_3_loss: 0.1017 - val_dense_5_accuracy: 0.9070 - val_dense_5_loss: 0.5443 - val_dense_7_accuracy: 0.8547 - val_dense_7_loss: 0.6185 - val_dense_9_accuracy: 0.9477 - val_dense_9_loss: 0.2531 - val_loss: 1.5575
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9829 - dense_1_loss: 0.0399 - dense_3_accuracy: 0.9720 - dense_3_loss: 0.1035 - dense_5_accuracy: 0.9818 - dense_5_loss: 0.0616 - dense_7_accuracy: 0.9453 - dense_7_loss: 0.1510 - dense_9_accuracy: 0.9735 - dense_9_loss: 0.0807 - loss: 0.4373 - val_dense_1_accuracy: 0.9767 - val_dense_1_loss: 0.0415 - val_dense_3_accuracy: 0.9593 - val_dense_3_loss: 0.1356 - val_dense_5_accuracy: 0.9186 - val_dense_5_loss: 0.4236 - val_dense_7_accuracy: 0.8605 - val_dense_7_loss: 0.5431 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.2736 - val_loss: 1.4152
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - dense_1_accuracy: 0.9921 - dense_1_loss: 0.0256 - dense_3_accuracy: 0.9597 - dense_3_loss: 0.1180 - dense_5_accuracy: 0.9722 - dense_5_loss: 0.0852 - dense_7_accuracy: 0.9339 - dense_7_loss: 0.1836 - dense_9_accuracy: 0.9654 - dense_9_loss: 0.0868 - loss: 0.4991 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 0.0412 - val_dense_3_accuracy: 0.9767 - val_dense_3_loss: 0.0902 - val_dense_5_accuracy: 0.9070 - val_dense_5_loss: 0.4624 - val_dense_7_accuracy: 0.8779 - val_dense_7_loss: 0.5387 - val_dense_9_accuracy: 0.9477 - val_dense_9_loss: 0.2506 - val_loss: 1.3923
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - dense_1_accuracy: 0.9890 - dense_1_loss: 0.0294 - dense_3_accuracy: 0.9551 - dense_3_loss: 0.0967 - dense_5_accuracy: 0.9726 - dense_5_loss: 0.0610 - dense_7_accuracy: 0.9175 - dense_7_loss: 0.1761 - dense_9_accuracy: 0.9699 - dense_9_loss: 0.0816 - loss: 0.4441 - val_dense_1_accuracy: 1.0000 - val_dense_1_loss: 0.0175 - val_dense_3_accuracy: 0.9826 - val_dense_3_loss: 0.0837 - val_dense_5_accuracy: 0.9128 - val_dense_5_loss: 0.4866 - val_dense_7_accuracy: 0.8779 - val_dense_7_loss: 0.5833 - val_dense_9_accuracy: 0.9302 - val_dense_9_loss: 0.2846 - val_loss: 1.4747
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - dense_1_accuracy: 0.9851 - dense_1_loss: 0.0454 - dense_3_accuracy: 0.9675 - dense_3_loss: 0.0905 - dense_5_accuracy: 0.9821 - dense_5_loss: 0.0670 - dense_7_accuracy: 0.9606 - dense_7_loss: 0.1420 - dense_9_accuracy: 0.9788 - dense_9_loss: 0.0784 - loss: 0.4236 - val_dense_1_accuracy: 0.9942 - val_dense_1_loss: 0.0188 - val_dense_3_accuracy: 0.9767 - val_dense_3_loss: 0.0790 - val_dense_5_accuracy: 0.9302 - val_dense_5_loss: 0.4208 - val_dense_7_accuracy: 0.8663 - val_dense_7_loss: 0.5263 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.2670 - val_loss: 1.3246
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - dense_1_accuracy: 0.9857 - dense_1_loss: 0.0335 - dense_3_accuracy: 0.9792 - dense_3_loss: 0.0702 - dense_5_accuracy: 0.9727 - dense_5_loss: 0.0835 - dense_7_accuracy: 0.9534 - dense_7_loss: 0.1477 - dense_9_accuracy: 0.9547 - dense_9_loss: 0.1058 - loss: 0.4394 - val_dense_1_accuracy: 0.9826 - val_dense_1_loss: 0.0292 - val_dense_3_accuracy: 0.9709 - val_dense_3_loss: 0.0969 - val_dense_5_accuracy: 0.9302 - val_dense_5_loss: 0.4959 - val_dense_7_accuracy: 0.8488 - val_dense_7_loss: 0.6090 - val_dense_9_accuracy: 0.9419 - val_dense_9_loss: 0.2794 - val_loss: 1.5319
# Epoch 49/50
#  3/11 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - dense_1_accuracy: 1.0000 - dense_1_loss: 0.0124 - dense_3_accuracy: 0.9627 - dense_3_loss: 0.0916 - dense_5_accuracy: 0.9540 - dense_5_loss: 0.0920 - dense_7_accuracy: 0.9384 - dense_7_loss: 0.1709 - dense_9_accuracy: 0.9722 - dense_9_loss: 0.0905 - loss: 0.4574

# %%
# Evaluate the model
print("Evaluating model...")
sc = model.evaluate(X_test, y_test, verbose=1)
print('Test Loss and accuracy:', sc)

# --- Add this function here ---
def evaluate_model(model, X_test, y_test):
    preds = model.predict(X_test)
    total_samples = X_test.shape[0]

    char_acc = []
    correct_full = 0

    for i in range(5):
        y_true = np.argmax(y_test[i], axis=1)
        y_pred = np.argmax(preds[i], axis=1)
        acc = np.mean(y_true == y_pred)
        char_acc.append(acc)

    # Full captcha accuracy (all 5 chars correct)
    for n in range(total_samples):
        pred_word = ''.join([sym[np.argmax(preds[i][n])] for i in range(5)])
        true_word = ''.join([sym[np.argmax(y_test[i][n])] for i in range(5)])
        if pred_word == true_word:
            correct_full += 1

    print("Character-level accuracy:", [round(a*100, 2) for a in char_acc])
    print("Full CAPTCHA accuracy:", round((correct_full/total_samples)*100, 2), "%")

# Call the function
evaluate_model(model, X_test, y_test)
# --- End new block ---

# Test predictions on sample images
print("\nTesting predictions...")
sample_files = ["8n5p3.png", "f2m8n.png", "dce8y.png", "3eny7.png", "npxb7.png"]

for filename in sample_files:
    file_path = os.path.join(path, "samples/samples", filename)
    pred_result = prediction(file_path)
    if pred_result:
        print(f"{filename}: {pred_result}")

# %%
# Display a sample image
# sample_img_path = os.path.join(path, "samples/samples/8n5p3.png")
# sample_img_path = os.path.join(path, "samples/samples/f2m8n.png")
# sample_img_path = os.path.join(path, "samples/samples/dce8y.png")
# sample_img_path = os.path.join(path, "samples/samples/3eny7.png")
sample_img_path = os.path.join(path, "samples/samples/npxb7.png")
if os.path.exists(sample_img_path):
    img = cv2.imread(sample_img_path, cv2.IMREAD_GRAYSCALE)
    if img is not None:
        plt.figure(figsize=(10, 3))
        plt.imshow(img, cmap='gray')
        plt.title(f"Sample CAPTCHA - Predicted: {prediction(sample_img_path)}")
        plt.axis('off')
        plt.show()

print("Training completed!")

# %%
# Save model
model.save("captcha_solver.keras")
print("Model saved as captcha_solver.keras")
